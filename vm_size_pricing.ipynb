# %% [markdown]
# #   <center> <span style="color:blue"> Azure Linux VM Size and Price at Glance </span> </center>

# %% [markdown]
# ##   <span style="color:blue"> Overview </span>
# <span  STYLE="color: black font-size: 12pt"> This notebook was developped to assist a customer who needed to have the VM Sizes and Prices for all available Azure VM shapes in one place to assist with database worload sizing.  </span>
# The key metrics for proper database workload sizing include: vCPU, memory, Max IOPS, Max IO Throughput MBPS, monthly cost, Max Data disks etc.
# Typical database workloads on IaaS VM are usually IO bound instead of CPU or Memory at the VM level. So it's critical to size properly based on the application workload IOPS and IO throughput MBPS. Azure VM size and price information can be found in https://docs.microsoft.com/en-us/azure/virtual-machines/sizes and https://azure.microsoft.com/en-us/pricing/details/virtual-machines/linux/; However the information is scattered in multiple linked pages which made it difficult to navigate and compare. The goal of this notebook is to combine all these information in one spreadsheet for easy comparison and decision making.
# We use BeautifulSoup to scrap the information from Microsoft document site and also https://azureprice.net/. The final product is an excel sheet with key metrics for all available Azure Linux VMs. The code would work for future released VM size as well as long as the embeded size table in the microsoft VM size page has the same/similar column formats.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import urllib.request
from urllib.parse import urlparse, parse_qs
import re, os, io, zipfile
import json
import requests
from requests import exceptions
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
from urllib.parse  import  urljoin

# %% [markdown]
# ##
# <span  STYLE="color: black font-size: 15pt"> For convenience, We extract VM price from azureprice.net which seems to be maintained reguarly. We use the west region for our price reference. Estimated monthly cost was computed. </span>

# %%
def requests_retry_session(retries=3, 
                           backoff_factor=0.3, 
                           status_forcelist=(500, 502, 503, 504), 
                           session=None):
    '''
    Use/Create an http(s) requests session that will retry a request.
    '''
    session = session or requests.Session()
    retry = Retry(total = retries, 
                  read = retries, 
                  connect = retries, 
                  backoff_factor = backoff_factor, 
                  status_forcelist = status_forcelist)
    adapter = HTTPAdapter(max_retries = retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    
    return session

    
def get_pricing_json(pricing_url):

        try:
            
            r = requests_retry_session().get(pricing_url, timeout = 300)
        except Exception as e:
            
            jsonfile = []
            exit
        r_content = r.content
         
         
        soup = BeautifulSoup(r_content, "html.parser")
        found=0
        for script in soup.find_all('script'):
           #print(i)
           mystr=' '.join(script.contents)
           if 'json =' in mystr:
               return mystr

# %%
pricing_json=get_pricing_json('https://azureprice.net/')[13:-5] 
print(pricing_json)
# Out:
# [{"name":"Standard_E96as_v4","canonicalname":"e96as_v4","numberOfCores":96,"osDiskSizeInMB":1047552,"resourceDiskSizeInMB":1376256,"memoryInMB":688128,"maxDataDiskCount":32,"regionId":"westus","regionName":"West US","currency":"USD","isTaxIncluded":false,"isLowPriority":false,"linuxPrice":6.72,"windowsPrice":11.136,"supportPremiumDisk":true,"pricePerMemoryLinux":0.01,"pricePerMemoryWindows":0.0166,"pricePerCoreLinux":0.07,"pricePerCoreWindows":0.116,"bestPriceRegion":"Central India / -43.3","bestSecondPriceRegion":"East US / -10","modifiedDate":"2020-11-15 10:01:12Z"},{"name":"Standard_E96-48as_v4","canonicalname":"e96-48as_v4","numberOfCores":96,"osDiskSizeInMB":1047552,"resourceDiskSizeInMB":1376256,"memoryInMB":688128,"maxDataDiskCount":32,"regionId":"westus","regionName":"West US","currency":"USD","isTaxIncluded":false,"isLowPriority":false,"linuxPrice":6.72,"windowsPrice":11.136,"supportPremiumDisk":true,"pricePerMemoryLinux":0.01,"pricePerMemoryWindows":0.0166,"pricePerCoreLinux":0.07,"pricePerCoreWindows":0.116,"bestPriceRegion":"East US / -10","bestSecondPriceRegion":"East US 2 / -10","modifiedDate":"2020-11-15 10:01:12Z"},{"name":"Standard_E96-24as_v4","canonicalname":"e96-24as_v4","numberOfCores":96,"osDiskSizeInMB":1047552,"resourceDiskSizeInMB":1376256,"memoryInMB":688128,"maxDataDiskCount":32,"regionId":"westus","regionName":"West US","currency":"USD","isTaxIncluded":false,"isLowPriority":false,"linuxPrice":6.72,"windowsPrice":11.136,"supportPremiumDisk":true,"pricePerMemoryLinux":0.01,"pricePerMemoryWindows":0.0166,"pricePerCoreLinux":0.07,"pricePerCoreWindows":0.116,"bestPriceRegion":"East US / -10","bestSecondPriceRegion":"East US 2 / -10","modifiedDate":"2020-11-15 10:01:12Z"},{"name":"Standard_E64as_v4","canonicalname":"e64as_v4","numberOfCores":64,"osDiskSizeInMB":1047552,"resourceDiskSizeInMB":884736,"memoryInMB":524288,"maxDataDiskCount":32,"regionId":"westus","regionName":"West US","currency":"USD","isTaxIncluded":false,"isLowPriority":false,"linuxPrice":4.48,"windowsPrice":7.424,"supportPremiumDisk":true,"pricePerMemoryLinux":0.0088,"pricePerMemoryWindows":0.0145,"pricePerCoreLinux":0.07,"pricePerCoreWindows":0.116,"bestPriceRegion":"Central India / -43.3","bestSecondPriceRegion":"East US / -10","modifiedDate":"2020-11-15 10:01:12Z"},{"name":"Standard_E64-32as_v4","canonicalname":"e64-32as_v4","numberOfCores":64,"osDiskSizeInMB":1047552,"resourceDiskSizeInMB":884736,"memoryInMB":524288,"maxDataDiskCount":32,"regionId":"westus","regionName":"West US","currency":"USD","isTaxIncluded":false,"isLowPriority":false,"linuxPrice":4.48,"windowsPrice":7.424,"supportPremiumDisk":true,"pricePerMemoryLinux":0.0088,"pricePerMemoryWindows":0.0145,"pricePerCoreLinux":0.07,"pricePerCoreWindows":0.116,"bestPriceRegion":"East US / -10","bestSecondPriceRegion":"East US 2 / -10","modifiedDate":"2020-11-15 10:01:12Z"},{"name":"Standard_E64-16as_v4","canonicalname":"e64-16as_v4","numberOfCores":64,"osDiskSizeInMB":1047552,"resourceDiskSizeInMB":884736,"memoryInMB":524288,"maxDataDiskCount":32,"regionId":"westus","regionName":"West US","currency":"USD","isTaxIncluded":false,"isLowPriority":false,"linuxPrice":4.48,"windowsPrice":7.424,"supportPremiumDisk":true,"pricePerMemoryLinux":0.0088,"pricePerMemoryWindows":0.0145,"pricePerCoreLinux":0.07,"pricePerCoreWindows":0.116,"bestPriceRegion":"East US / -10","bestSecondPriceRegion":"East US 2 / -10","modifiedDate":"2020-11-15 10:01:12Z"},{"name":"Standard_E48as_v4","canonicalname":"e48as_v4","numberOfCores":48,"osDiskSizeInMB":1047552,"resourceDiskSizeInMB":786432,"memoryInMB":393216,"maxDataDiskCount":32,"regionId":"westus","regionName":"West US","currency":"USD","isTaxIncluded":false,"isLowPriority":false,"linuxPrice":3.36,"windowsPrice":5.568,"supportPremiumDisk":true,"pricePerMemoryLinux":0.0087,"pricePerMemoryWindows":0.0145,"pricePerCoreLinux":0.07,"pricePerCoreWindows":0.116,"bestPriceRegion":"Central India / -43.3","bestSecondPriceRegion":"East US / -10","modifiedDate":"2020 ...

# %%
jdata = json.loads(pricing_json)
for d in jdata:
    for key, value in d.items():
        print(key, value)
# Out:
# name Standard_E96as_v4
# canonicalname e96as_v4
# numberOfCores 96
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 1376256
# memoryInMB 688128
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 6.72
# windowsPrice 11.136
# supportPremiumDisk True
# pricePerMemoryLinux 0.01
# pricePerMemoryWindows 0.0166
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion Central India / -43.3
# bestSecondPriceRegion East US / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E96-48as_v4
# canonicalname e96-48as_v4
# numberOfCores 96
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 1376256
# memoryInMB 688128
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 6.72
# windowsPrice 11.136
# supportPremiumDisk True
# pricePerMemoryLinux 0.01
# pricePerMemoryWindows 0.0166
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion East US / -10
# bestSecondPriceRegion East US 2 / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E96-24as_v4
# canonicalname e96-24as_v4
# numberOfCores 96
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 1376256
# memoryInMB 688128
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 6.72
# windowsPrice 11.136
# supportPremiumDisk True
# pricePerMemoryLinux 0.01
# pricePerMemoryWindows 0.0166
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion East US / -10
# bestSecondPriceRegion East US 2 / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E64as_v4
# canonicalname e64as_v4
# numberOfCores 64
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 884736
# memoryInMB 524288
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 4.48
# windowsPrice 7.424
# supportPremiumDisk True
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion Central India / -43.3
# bestSecondPriceRegion East US / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E64-32as_v4
# canonicalname e64-32as_v4
# numberOfCores 64
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 884736
# memoryInMB 524288
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 4.48
# windowsPrice 7.424
# supportPremiumDisk True
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion East US / -10
# bestSecondPriceRegion East US 2 / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E64-16as_v4
# canonicalname e64-16as_v4
# numberOfCores 64
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 884736
# memoryInMB 524288
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 4.48
# windowsPrice 7.424
# supportPremiumDisk True
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion East US / -10
# bestSecondPriceRegion East US 2 / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E48as_v4
# canonicalname e48as_v4
# numberOfCores 48
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 786432
# memoryInMB 393216
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 3.36
# windowsPrice 5.568
# supportPremiumDisk True
# pricePerMemoryLinux 0.0087
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion Central India / -43.3
# bestSecondPriceRegion East US / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E32as_v4
# canonicalname e32as_v4
# numberOfCores 32
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 524288
# memoryInMB 262144
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 2.24
# windowsPrice 3.712
# supportPremiumDisk True
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion Central India / -43.3
# bestSecondPriceRegion East US / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E32-16as_v4
# canonicalname e32-16as_v4
# numberOfCores 32
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 524288
# memoryInMB 262144
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 2.24
# windowsPrice 3.712
# supportPremiumDisk True
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion East US / -10
# bestSecondPriceRegion East US 2 / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E32-8as_v4
# canonicalname e32-8as_v4
# numberOfCores 32
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 524288
# memoryInMB 262144
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 2.24
# windowsPrice 3.712
# supportPremiumDisk True
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion East US / -10
# bestSecondPriceRegion East US 2 / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E20as_v4
# canonicalname e20as_v4
# numberOfCores 20
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 327680
# memoryInMB 163840
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.4
# windowsPrice 2.32
# supportPremiumDisk True
# pricePerMemoryLinux 0.0087
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion Central India / -43.2
# bestSecondPriceRegion East US / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E16as_v4
# canonicalname e16as_v4
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 262144
# memoryInMB 131072
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.12
# windowsPrice 1.856
# supportPremiumDisk True
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion Central India / -43.2
# bestSecondPriceRegion East US / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E16-8as_v4
# canonicalname e16-8as_v4
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 262144
# memoryInMB 131072
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.12
# windowsPrice 1.856
# supportPremiumDisk True
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion East US / -10
# bestSecondPriceRegion East US 2 / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E16-4as_v4
# canonicalname e16-4as_v4
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 262144
# memoryInMB 131072
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.12
# windowsPrice 1.856
# supportPremiumDisk True
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion East US / -10
# bestSecondPriceRegion East US 2 / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E8as_v4
# canonicalname e8as_v4
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 131072
# memoryInMB 65536
# maxDataDiskCount 16
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.56
# windowsPrice 0.928
# supportPremiumDisk True
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion Central India / -43.2
# bestSecondPriceRegion East US / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E8-4as_v4
# canonicalname e8-4as_v4
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 131072
# memoryInMB 65536
# maxDataDiskCount 16
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.56
# windowsPrice 0.928
# supportPremiumDisk True
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion East US / -10
# bestSecondPriceRegion East US 2 / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E8-2as_v4
# canonicalname e8-2as_v4
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 131072
# memoryInMB 65536
# maxDataDiskCount 16
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.56
# windowsPrice 0.928
# supportPremiumDisk True
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion East US / -10
# bestSecondPriceRegion East US 2 / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E4as_v4
# canonicalname e4as_v4
# numberOfCores 4
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 65536
# memoryInMB 32768
# maxDataDiskCount 8
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.28
# windowsPrice 0.464
# supportPremiumDisk True
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion Central India / -43.2
# bestSecondPriceRegion East US / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E4-2as_v4
# canonicalname e4-2as_v4
# numberOfCores 4
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 65536
# memoryInMB 32768
# maxDataDiskCount 8
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.28
# windowsPrice 0.464
# supportPremiumDisk True
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion East US / -10
# bestSecondPriceRegion East US 2 / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E2as_v4
# canonicalname e2as_v4
# numberOfCores 2
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 32768
# memoryInMB 16384
# maxDataDiskCount 4
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.14
# windowsPrice 0.232
# supportPremiumDisk True
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion Central India / -42.9
# bestSecondPriceRegion East US / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E96a_v4
# canonicalname e96a_v4
# numberOfCores 96
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 2457600
# memoryInMB 688128
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 6.72
# windowsPrice 11.136
# supportPremiumDisk False
# pricePerMemoryLinux 0.01
# pricePerMemoryWindows 0.0166
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion Central India / -43.3
# bestSecondPriceRegion East US / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E64a_v4
# canonicalname e64a_v4
# numberOfCores 64
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 1638400
# memoryInMB 524288
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 4.48
# windowsPrice 7.424
# supportPremiumDisk False
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion Central India / -43.3
# bestSecondPriceRegion East US / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E48a_v4
# canonicalname e48a_v4
# numberOfCores 48
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 1228800
# memoryInMB 393216
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 3.36
# windowsPrice 5.568
# supportPremiumDisk False
# pricePerMemoryLinux 0.0087
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion Central India / -43.3
# bestSecondPriceRegion East US / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E32a_v4
# canonicalname e32a_v4
# numberOfCores 32
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 819200
# memoryInMB 262144
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 2.24
# windowsPrice 3.712
# supportPremiumDisk False
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion Central India / -43.3
# bestSecondPriceRegion East US / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E20a_v4
# canonicalname e20a_v4
# numberOfCores 20
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 512000
# memoryInMB 163840
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.4
# windowsPrice 2.32
# supportPremiumDisk False
# pricePerMemoryLinux 0.0087
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion Central India / -43.2
# bestSecondPriceRegion East US / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E16a_v4
# canonicalname e16a_v4
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 409600
# memoryInMB 131072
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.12
# windowsPrice 1.856
# supportPremiumDisk False
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion Central India / -43.2
# bestSecondPriceRegion East US / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E8a_v4
# canonicalname e8a_v4
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 204800
# memoryInMB 65536
# maxDataDiskCount 16
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.56
# windowsPrice 0.928
# supportPremiumDisk False
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion Central India / -43.2
# bestSecondPriceRegion East US / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E4a_v4
# canonicalname e4a_v4
# numberOfCores 4
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 102400
# memoryInMB 32768
# maxDataDiskCount 8
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.28
# windowsPrice 0.464
# supportPremiumDisk False
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion Central India / -43.2
# bestSecondPriceRegion East US / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_E2a_v4
# canonicalname e2a_v4
# numberOfCores 2
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 51200
# memoryInMB 16384
# maxDataDiskCount 4
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.14
# windowsPrice 0.232
# supportPremiumDisk False
# pricePerMemoryLinux 0.0088
# pricePerMemoryWindows 0.0145
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.116
# bestPriceRegion Central India / -42.9
# bestSecondPriceRegion East US / -10
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D96as_v4
# canonicalname d96as_v4
# numberOfCores 96
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 786432
# memoryInMB 393216
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 5.376
# windowsPrice 9.792
# supportPremiumDisk True
# pricePerMemoryLinux 0.014
# pricePerMemoryWindows 0.0255
# pricePerCoreLinux 0.056
# pricePerCoreWindows 0.102
# bestPriceRegion Central India / -44.9
# bestSecondPriceRegion East US / -14.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D64as_v4
# canonicalname d64as_v4
# numberOfCores 64
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 524288
# memoryInMB 262144
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 3.584
# windowsPrice 6.528
# supportPremiumDisk True
# pricePerMemoryLinux 0.014
# pricePerMemoryWindows 0.0255
# pricePerCoreLinux 0.056
# pricePerCoreWindows 0.102
# bestPriceRegion Central India / -44.9
# bestSecondPriceRegion East US / -14.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D48as_v4
# canonicalname d48as_v4
# numberOfCores 48
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 393216
# memoryInMB 196608
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 2.688
# windowsPrice 4.896
# supportPremiumDisk True
# pricePerMemoryLinux 0.014
# pricePerMemoryWindows 0.0255
# pricePerCoreLinux 0.056
# pricePerCoreWindows 0.102
# bestPriceRegion Central India / -44.9
# bestSecondPriceRegion East US / -14.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D32as_v4
# canonicalname d32as_v4
# numberOfCores 32
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 262144
# memoryInMB 131072
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.792
# windowsPrice 3.264
# supportPremiumDisk True
# pricePerMemoryLinux 0.014
# pricePerMemoryWindows 0.0255
# pricePerCoreLinux 0.056
# pricePerCoreWindows 0.102
# bestPriceRegion Central India / -44.9
# bestSecondPriceRegion East US / -14.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D16as_v4
# canonicalname d16as_v4
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 131072
# memoryInMB 65536
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.896
# windowsPrice 1.632
# supportPremiumDisk True
# pricePerMemoryLinux 0.014
# pricePerMemoryWindows 0.0255
# pricePerCoreLinux 0.056
# pricePerCoreWindows 0.102
# bestPriceRegion Central India / -44.9
# bestSecondPriceRegion East US / -14.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D8as_v4
# canonicalname d8as_v4
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 65536
# memoryInMB 32768
# maxDataDiskCount 16
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.448
# windowsPrice 0.816
# supportPremiumDisk True
# pricePerMemoryLinux 0.014
# pricePerMemoryWindows 0.0255
# pricePerCoreLinux 0.056
# pricePerCoreWindows 0.102
# bestPriceRegion Central India / -44.9
# bestSecondPriceRegion East US / -14.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D4as_v4
# canonicalname d4as_v4
# numberOfCores 4
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 32768
# memoryInMB 16384
# maxDataDiskCount 8
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.224
# windowsPrice 0.408
# supportPremiumDisk True
# pricePerMemoryLinux 0.014
# pricePerMemoryWindows 0.0255
# pricePerCoreLinux 0.056
# pricePerCoreWindows 0.102
# bestPriceRegion Central India / -45
# bestSecondPriceRegion East US / -14.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D2as_v4
# canonicalname d2as_v4
# numberOfCores 2
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 16384
# memoryInMB 8192
# maxDataDiskCount 4
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.112
# windowsPrice 0.204
# supportPremiumDisk True
# pricePerMemoryLinux 0.014
# pricePerMemoryWindows 0.0255
# pricePerCoreLinux 0.056
# pricePerCoreWindows 0.102
# bestPriceRegion Central India / -44.5
# bestSecondPriceRegion East US / -14.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D96a_v4
# canonicalname d96a_v4
# numberOfCores 96
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 2457600
# memoryInMB 393216
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 5.376
# windowsPrice 9.792
# supportPremiumDisk False
# pricePerMemoryLinux 0.014
# pricePerMemoryWindows 0.0255
# pricePerCoreLinux 0.056
# pricePerCoreWindows 0.102
# bestPriceRegion Central India / -44.9
# bestSecondPriceRegion East US / -14.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D64a_v4
# canonicalname d64a_v4
# numberOfCores 64
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 1638400
# memoryInMB 262144
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 3.584
# windowsPrice 6.528
# supportPremiumDisk False
# pricePerMemoryLinux 0.014
# pricePerMemoryWindows 0.0255
# pricePerCoreLinux 0.056
# pricePerCoreWindows 0.102
# bestPriceRegion Central India / -44.9
# bestSecondPriceRegion East US / -14.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D48a_v4
# canonicalname d48a_v4
# numberOfCores 48
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 1228800
# memoryInMB 196608
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 2.688
# windowsPrice 4.896
# supportPremiumDisk False
# pricePerMemoryLinux 0.014
# pricePerMemoryWindows 0.0255
# pricePerCoreLinux 0.056
# pricePerCoreWindows 0.102
# bestPriceRegion Central India / -44.9
# bestSecondPriceRegion East US / -14.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D32a_v4
# canonicalname d32a_v4
# numberOfCores 32
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 819200
# memoryInMB 131072
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.792
# windowsPrice 3.264
# supportPremiumDisk False
# pricePerMemoryLinux 0.014
# pricePerMemoryWindows 0.0255
# pricePerCoreLinux 0.056
# pricePerCoreWindows 0.102
# bestPriceRegion Central India / -44.9
# bestSecondPriceRegion East US / -14.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D16a_v4
# canonicalname d16a_v4
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 409600
# memoryInMB 65536
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.896
# windowsPrice 1.632
# supportPremiumDisk False
# pricePerMemoryLinux 0.014
# pricePerMemoryWindows 0.0255
# pricePerCoreLinux 0.056
# pricePerCoreWindows 0.102
# bestPriceRegion Central India / -44.9
# bestSecondPriceRegion East US / -14.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D8a_v4
# canonicalname d8a_v4
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 204800
# memoryInMB 32768
# maxDataDiskCount 16
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.448
# windowsPrice 0.816
# supportPremiumDisk False
# pricePerMemoryLinux 0.014
# pricePerMemoryWindows 0.0255
# pricePerCoreLinux 0.056
# pricePerCoreWindows 0.102
# bestPriceRegion Central India / -44.9
# bestSecondPriceRegion East US / -14.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D4a_v4
# canonicalname d4a_v4
# numberOfCores 4
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 102400
# memoryInMB 16384
# maxDataDiskCount 8
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.224
# windowsPrice 0.408
# supportPremiumDisk False
# pricePerMemoryLinux 0.014
# pricePerMemoryWindows 0.0255
# pricePerCoreLinux 0.056
# pricePerCoreWindows 0.102
# bestPriceRegion Central India / -45
# bestSecondPriceRegion East US / -14.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D2a_v4
# canonicalname d2a_v4
# numberOfCores 2
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 51200
# memoryInMB 8192
# maxDataDiskCount 4
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.112
# windowsPrice 0.204
# supportPremiumDisk False
# pricePerMemoryLinux 0.014
# pricePerMemoryWindows 0.0255
# pricePerCoreLinux 0.056
# pricePerCoreWindows 0.102
# bestPriceRegion Central India / -44.5
# bestSecondPriceRegion East US / -14.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_M416ms_v2
# canonicalname m416ms_v2
# numberOfCores 416
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 8388608
# memoryInMB 11673600
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 128.9
# windowsPrice 148.03
# supportPremiumDisk True
# pricePerMemoryLinux 0.0113
# pricePerMemoryWindows 0.013
# pricePerCoreLinux 0.3099
# pricePerCoreWindows 0.3558
# bestPriceRegion East US / -23.1
# bestSecondPriceRegion East US 2 / -23.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_M416s_v2
# canonicalname m416s_v2
# numberOfCores 416
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 8388608
# memoryInMB 5836800
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 64.454
# windowsPrice 83.59
# supportPremiumDisk True
# pricePerMemoryLinux 0.0113
# pricePerMemoryWindows 0.0147
# pricePerCoreLinux 0.1549
# pricePerCoreWindows 0.2009
# bestPriceRegion East US / -23.1
# bestSecondPriceRegion East US 2 / -23.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_M208s_v2
# canonicalname m208s_v2
# numberOfCores 208
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 4194304
# memoryInMB 2918400
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 29.003
# windowsPrice 38.571
# supportPremiumDisk True
# pricePerMemoryLinux 0.0102
# pricePerMemoryWindows 0.0135
# pricePerCoreLinux 0.1394
# pricePerCoreWindows 0.1854
# bestPriceRegion East US / -23.1
# bestSecondPriceRegion East US 2 / -23.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_M208ms_v2
# canonicalname m208ms_v2
# numberOfCores 208
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 4194304
# memoryInMB 5836800
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 58.006
# windowsPrice 67.574
# supportPremiumDisk True
# pricePerMemoryLinux 0.0102
# pricePerMemoryWindows 0.0119
# pricePerCoreLinux 0.2789
# pricePerCoreWindows 0.3249
# bestPriceRegion East US / -23.1
# bestSecondPriceRegion East US 2 / -23.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_H16mr
# canonicalname h16mr
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 2048000
# memoryInMB 229376
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 2.861
# windowsPrice 4.742
# supportPremiumDisk False
# pricePerMemoryLinux 0.0128
# pricePerMemoryWindows 0.0212
# pricePerCoreLinux 0.1788
# pricePerCoreWindows 0.2964
# bestPriceRegion West US 2 / -50.8
# bestSecondPriceRegion South Central US / -45.9
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_H16r
# canonicalname h16r
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 2048000
# memoryInMB 114688
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.281
# windowsPrice 3.54
# supportPremiumDisk False
# pricePerMemoryLinux 0.0114
# pricePerMemoryWindows 0.0316
# pricePerCoreLinux 0.0801
# pricePerCoreWindows 0.2213
# bestPriceRegion West US / 0
# bestSecondPriceRegion Central India / 2.8
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_H16m
# canonicalname h16m
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 2048000
# memoryInMB 229376
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 2.601
# windowsPrice 2.297
# supportPremiumDisk False
# pricePerMemoryLinux 0.0116
# pricePerMemoryWindows 0.0103
# pricePerCoreLinux 0.1626
# pricePerCoreWindows 0.1436
# bestPriceRegion West US 2 / -50.8
# bestSecondPriceRegion South Central US / -45.9
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_H8m
# canonicalname h8m
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 1024000
# memoryInMB 114688
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.301
# windowsPrice 2.156
# supportPremiumDisk False
# pricePerMemoryLinux 0.0116
# pricePerMemoryWindows 0.0193
# pricePerCoreLinux 0.1626
# pricePerCoreWindows 0.2695
# bestPriceRegion South Central US / -45.9
# bestSecondPriceRegion UK South / -41
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_H16
# canonicalname h16
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 2048000
# memoryInMB 114688
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.941
# windowsPrice 1.901
# supportPremiumDisk False
# pricePerMemoryLinux 0.0173
# pricePerMemoryWindows 0.017
# pricePerCoreLinux 0.1213
# pricePerCoreWindows 0.1188
# bestPriceRegion North Europe / -40
# bestSecondPriceRegion Japan East / -29.2
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_H8
# canonicalname h8
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 1024000
# memoryInMB 57344
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.582
# windowsPrice 0.95
# supportPremiumDisk False
# pricePerMemoryLinux 0.0104
# pricePerMemoryWindows 0.017
# pricePerCoreLinux 0.0728
# pricePerCoreWindows 0.1188
# bestPriceRegion North Central US / -6.7
# bestSecondPriceRegion UK South / -1.5
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_NV48s_v3
# canonicalname nv48s_v3
# numberOfCores 48
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 1376256
# memoryInMB 458752
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 4.56
# windowsPrice 6.768
# supportPremiumDisk True
# pricePerMemoryLinux 0.0102
# pricePerMemoryWindows 0.0151
# pricePerCoreLinux 0.095
# pricePerCoreWindows 0.141
# bestPriceRegion East US / 0
# bestSecondPriceRegion East US 2 / 0
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_NV24s_v3
# canonicalname nv24s_v3
# numberOfCores 24
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 688128
# memoryInMB 229376
# maxDataDiskCount 24
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 2.28
# windowsPrice 3.384
# supportPremiumDisk True
# pricePerMemoryLinux 0.0102
# pricePerMemoryWindows 0.0151
# pricePerCoreLinux 0.095
# pricePerCoreWindows 0.141
# bestPriceRegion East US / 0
# bestSecondPriceRegion East US 2 / 0
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_NV12s_v3
# canonicalname nv12s_v3
# numberOfCores 12
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 344064
# memoryInMB 114688
# maxDataDiskCount 12
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.14
# windowsPrice 1.692
# supportPremiumDisk True
# pricePerMemoryLinux 0.0102
# pricePerMemoryWindows 0.0151
# pricePerCoreLinux 0.095
# pricePerCoreWindows 0.141
# bestPriceRegion East US / 0
# bestSecondPriceRegion East US 2 / 0
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_NV24s_v2
# canonicalname nv24s_v2
# numberOfCores 24
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 1376256
# memoryInMB 458752
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 3.069
# windowsPrice 0.0
# supportPremiumDisk True
# pricePerMemoryLinux 0.0069
# pricePerMemoryWindows 0.0
# pricePerCoreLinux 0.1279
# pricePerCoreWindows 0.0
# bestPriceRegion South Central US / -10.9
# bestSecondPriceRegion West US / 0
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_NV12s_v2
# canonicalname nv12s_v2
# numberOfCores 12
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 688128
# memoryInMB 229376
# maxDataDiskCount 24
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.534
# windowsPrice 1.81
# supportPremiumDisk True
# pricePerMemoryLinux 0.0068
# pricePerMemoryWindows 0.0081
# pricePerCoreLinux 0.1278
# pricePerCoreWindows 0.1508
# bestPriceRegion South Central US / -10.8
# bestSecondPriceRegion West US / 0
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_NV6s_v2
# canonicalname nv6s_v2
# numberOfCores 6
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 344064
# memoryInMB 114688
# maxDataDiskCount 12
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.767
# windowsPrice 0.905
# supportPremiumDisk True
# pricePerMemoryLinux 0.0068
# pricePerMemoryWindows 0.0081
# pricePerCoreLinux 0.1278
# pricePerCoreWindows 0.1508
# bestPriceRegion South Central US / -10.8
# bestSecondPriceRegion West US / 0
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_A11
# canonicalname a11
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 391168
# memoryInMB 114688
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.56
# windowsPrice 2.346
# supportPremiumDisk False
# pricePerMemoryLinux 0.0139
# pricePerMemoryWindows 0.0209
# pricePerCoreLinux 0.0975
# pricePerCoreWindows 0.1466
# bestPriceRegion South Central US / -10.3
# bestSecondPriceRegion East US / 0
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_A10
# canonicalname a10
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 391168
# memoryInMB 57344
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.78
# windowsPrice 1.173
# supportPremiumDisk False
# pricePerMemoryLinux 0.0139
# pricePerMemoryWindows 0.0209
# pricePerCoreLinux 0.0975
# pricePerCoreWindows 0.1466
# bestPriceRegion South Central US / -10.3
# bestSecondPriceRegion East US / 0
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_A9
# canonicalname a9
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 391168
# memoryInMB 114688
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.95
# windowsPrice 2.933
# supportPremiumDisk False
# pricePerMemoryLinux 0.0174
# pricePerMemoryWindows 0.0262
# pricePerCoreLinux 0.1219
# pricePerCoreWindows 0.1833
# bestPriceRegion South Central US / -10.3
# bestSecondPriceRegion East US / 0
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_A8
# canonicalname a8
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 391168
# memoryInMB 57344
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.975
# windowsPrice 1.466
# supportPremiumDisk False
# pricePerMemoryLinux 0.0174
# pricePerMemoryWindows 0.0262
# pricePerCoreLinux 0.1219
# pricePerCoreWindows 0.1833
# bestPriceRegion South Central US / -10.3
# bestSecondPriceRegion East US / 0
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_M128s
# canonicalname m128s
# numberOfCores 128
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 4096000
# memoryInMB 2048000
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 17.339
# windowsPrice 23.227
# supportPremiumDisk True
# pricePerMemoryLinux 0.0087
# pricePerMemoryWindows 0.0116
# pricePerCoreLinux 0.1355
# pricePerCoreWindows 0.1815
# bestPriceRegion East US / -23.1
# bestSecondPriceRegion East US 2 / -23.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_M128ms
# canonicalname m128ms
# numberOfCores 128
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 4096000
# memoryInMB 3891200
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 34.694
# windowsPrice 40.582
# supportPremiumDisk True
# pricePerMemoryLinux 0.0091
# pricePerMemoryWindows 0.0107
# pricePerCoreLinux 0.271
# pricePerCoreWindows 0.317
# bestPriceRegion East US / -23.1
# bestSecondPriceRegion East US 2 / -23.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_M64s
# canonicalname m64s
# numberOfCores 64
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 2048000
# memoryInMB 1024000
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 8.67
# windowsPrice 11.614
# supportPremiumDisk True
# pricePerMemoryLinux 0.0087
# pricePerMemoryWindows 0.0116
# pricePerCoreLinux 0.1355
# pricePerCoreWindows 0.1815
# bestPriceRegion East US / -23.1
# bestSecondPriceRegion East US 2 / -23.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_M64ms
# canonicalname m64ms
# numberOfCores 64
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 2048000
# memoryInMB 1792000
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 17.347
# windowsPrice 20.291
# supportPremiumDisk True
# pricePerMemoryLinux 0.0099
# pricePerMemoryWindows 0.0116
# pricePerCoreLinux 0.271
# pricePerCoreWindows 0.317
# bestPriceRegion East US / -40.4
# bestSecondPriceRegion East US 2 / -40.4
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_M64ls
# canonicalname m64ls
# numberOfCores 64
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 2048000
# memoryInMB 524288
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 6.403
# windowsPrice 9.347
# supportPremiumDisk True
# pricePerMemoryLinux 0.0125
# pricePerMemoryWindows 0.0183
# pricePerCoreLinux 0.1
# pricePerCoreWindows 0.146
# bestPriceRegion East US / -15.4
# bestSecondPriceRegion East US 2 / -15.4
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_M32ts
# canonicalname m32ts
# numberOfCores 32
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 1024000
# memoryInMB 196608
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 3.016
# windowsPrice 4.488
# supportPremiumDisk True
# pricePerMemoryLinux 0.0157
# pricePerMemoryWindows 0.0234
# pricePerCoreLinux 0.0943
# pricePerCoreWindows 0.1403
# bestPriceRegion East US / -10.2
# bestSecondPriceRegion East US 2 / -10.2
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_M32ms
# canonicalname m32ms
# numberOfCores 32
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 1024000
# memoryInMB 896000
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 7.99
# windowsPrice 9.462
# supportPremiumDisk True
# pricePerMemoryLinux 0.0091
# pricePerMemoryWindows 0.0108
# pricePerCoreLinux 0.2497
# pricePerCoreWindows 0.2957
# bestPriceRegion East US / -23.1
# bestSecondPriceRegion East US 2 / -23.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_M32ls
# canonicalname m32ls
# numberOfCores 32
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 1024000
# memoryInMB 262144
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 3.201
# windowsPrice 4.673
# supportPremiumDisk True
# pricePerMemoryLinux 0.0125
# pricePerMemoryWindows 0.0183
# pricePerCoreLinux 0.1
# pricePerCoreWindows 0.146
# bestPriceRegion East US / -10.2
# bestSecondPriceRegion East US 2 / -10.2
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_M16ms
# canonicalname m16ms
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 512000
# memoryInMB 448000
# maxDataDiskCount 16
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 3.995
# windowsPrice 4.731
# supportPremiumDisk True
# pricePerMemoryLinux 0.0091
# pricePerMemoryWindows 0.0108
# pricePerCoreLinux 0.2497
# pricePerCoreWindows 0.2957
# bestPriceRegion East US / -23.1
# bestSecondPriceRegion East US 2 / -23.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_M8ms
# canonicalname m8ms
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 256000
# memoryInMB 224000
# maxDataDiskCount 8
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.997
# windowsPrice 2.365
# supportPremiumDisk True
# pricePerMemoryLinux 0.0091
# pricePerMemoryWindows 0.0108
# pricePerCoreLinux 0.2496
# pricePerCoreWindows 0.2956
# bestPriceRegion East US / -23.1
# bestSecondPriceRegion East US 2 / -23.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_L32s
# canonicalname l32s
# numberOfCores 32
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 5765120
# memoryInMB 262144
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 2.752
# windowsPrice 4.224
# supportPremiumDisk True
# pricePerMemoryLinux 0.0107
# pricePerMemoryWindows 0.0165
# pricePerCoreLinux 0.086
# pricePerCoreWindows 0.132
# bestPriceRegion West US 2 / -9.3
# bestSecondPriceRegion East US 2 / -0.2
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_L16s
# canonicalname l16s
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 2874368
# memoryInMB 131072
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.376
# windowsPrice 2.112
# supportPremiumDisk True
# pricePerMemoryLinux 0.0107
# pricePerMemoryWindows 0.0165
# pricePerCoreLinux 0.086
# pricePerCoreWindows 0.132
# bestPriceRegion West US 2 / -9.3
# bestSecondPriceRegion East US 2 / -0.2
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_L8s
# canonicalname l8s
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 1421312
# memoryInMB 65536
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.688
# windowsPrice 1.056
# supportPremiumDisk True
# pricePerMemoryLinux 0.0107
# pricePerMemoryWindows 0.0165
# pricePerCoreLinux 0.086
# pricePerCoreWindows 0.132
# bestPriceRegion West US 2 / -9.3
# bestSecondPriceRegion East US 2 / -0.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_L4s
# canonicalname l4s
# numberOfCores 4
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 694272
# memoryInMB 32768
# maxDataDiskCount 16
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.344
# windowsPrice 0.528
# supportPremiumDisk True
# pricePerMemoryLinux 0.0107
# pricePerMemoryWindows 0.0165
# pricePerCoreLinux 0.086
# pricePerCoreWindows 0.132
# bestPriceRegion West US 2 / -9.3
# bestSecondPriceRegion East US 2 / -0.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_GS5
# canonicalname gs5
# numberOfCores 32
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 917504
# memoryInMB 458752
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 8.69
# windowsPrice 9.65
# supportPremiumDisk True
# pricePerMemoryLinux 0.0194
# pricePerMemoryWindows 0.0215
# pricePerCoreLinux 0.2716
# pricePerCoreWindows 0.3016
# bestPriceRegion UK South / -19.1
# bestSecondPriceRegion Canada Central / -10.9
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_GS4
# canonicalname gs4
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 458752
# memoryInMB 229376
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 4.88
# windowsPrice 5.36
# supportPremiumDisk True
# pricePerMemoryLinux 0.0218
# pricePerMemoryWindows 0.0239
# pricePerCoreLinux 0.305
# pricePerCoreWindows 0.335
# bestPriceRegion UK South / -28
# bestSecondPriceRegion Canada Central / -20.7
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_GS3
# canonicalname gs3
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 229376
# memoryInMB 114688
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 2.44
# windowsPrice 2.68
# supportPremiumDisk True
# pricePerMemoryLinux 0.0218
# pricePerMemoryWindows 0.0239
# pricePerCoreLinux 0.305
# pricePerCoreWindows 0.335
# bestPriceRegion UK South / -28
# bestSecondPriceRegion Canada Central / -20.7
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_GS2
# canonicalname gs2
# numberOfCores 4
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 114688
# memoryInMB 57344
# maxDataDiskCount 16
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.22
# windowsPrice 1.34
# supportPremiumDisk True
# pricePerMemoryLinux 0.0218
# pricePerMemoryWindows 0.0239
# pricePerCoreLinux 0.305
# pricePerCoreWindows 0.335
# bestPriceRegion UK South / -28
# bestSecondPriceRegion Canada Central / -20.7
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_GS1
# canonicalname gs1
# numberOfCores 2
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 57344
# memoryInMB 28672
# maxDataDiskCount 8
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.61
# windowsPrice 0.67
# supportPremiumDisk True
# pricePerMemoryLinux 0.0218
# pricePerMemoryWindows 0.0239
# pricePerCoreLinux 0.305
# pricePerCoreWindows 0.335
# bestPriceRegion UK South / -28
# bestSecondPriceRegion Canada Central / -20.7
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_G5
# canonicalname g5
# numberOfCores 32
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 6291456
# memoryInMB 458752
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 8.69
# windowsPrice 9.65
# supportPremiumDisk False
# pricePerMemoryLinux 0.0194
# pricePerMemoryWindows 0.0215
# pricePerCoreLinux 0.2716
# pricePerCoreWindows 0.3016
# bestPriceRegion UK South / -19.1
# bestSecondPriceRegion Canada Central / -10.9
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_G4
# canonicalname g4
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 3145728
# memoryInMB 229376
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 4.88
# windowsPrice 5.36
# supportPremiumDisk False
# pricePerMemoryLinux 0.0218
# pricePerMemoryWindows 0.0239
# pricePerCoreLinux 0.305
# pricePerCoreWindows 0.335
# bestPriceRegion UK South / -28
# bestSecondPriceRegion Canada Central / -20.7
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_G3
# canonicalname g3
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 1572864
# memoryInMB 114688
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 2.44
# windowsPrice 2.68
# supportPremiumDisk False
# pricePerMemoryLinux 0.0218
# pricePerMemoryWindows 0.0239
# pricePerCoreLinux 0.305
# pricePerCoreWindows 0.335
# bestPriceRegion UK South / -28
# bestSecondPriceRegion Canada Central / -20.7
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_G2
# canonicalname g2
# numberOfCores 4
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 786432
# memoryInMB 57344
# maxDataDiskCount 16
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.22
# windowsPrice 1.34
# supportPremiumDisk False
# pricePerMemoryLinux 0.0218
# pricePerMemoryWindows 0.0239
# pricePerCoreLinux 0.305
# pricePerCoreWindows 0.335
# bestPriceRegion UK South / -28
# bestSecondPriceRegion Canada Central / -20.7
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_G1
# canonicalname g1
# numberOfCores 2
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 393216
# memoryInMB 28672
# maxDataDiskCount 8
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.61
# windowsPrice 0.67
# supportPremiumDisk False
# pricePerMemoryLinux 0.0218
# pricePerMemoryWindows 0.0239
# pricePerCoreLinux 0.305
# pricePerCoreWindows 0.335
# bestPriceRegion UK South / -28
# bestSecondPriceRegion Canada Central / -20.7
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_F72s_v2
# canonicalname f72s_v2
# numberOfCores 72
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 589824
# memoryInMB 147456
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 3.816
# windowsPrice 7.128
# supportPremiumDisk True
# pricePerMemoryLinux 0.0265
# pricePerMemoryWindows 0.0495
# pricePerCoreLinux 0.053
# pricePerCoreWindows 0.099
# bestPriceRegion East US / -20.2
# bestSecondPriceRegion East US 2 / -20.2
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_F64s_v2
# canonicalname f64s_v2
# numberOfCores 64
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 524288
# memoryInMB 131072
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 3.392
# windowsPrice 6.336
# supportPremiumDisk True
# pricePerMemoryLinux 0.0265
# pricePerMemoryWindows 0.0495
# pricePerCoreLinux 0.053
# pricePerCoreWindows 0.099
# bestPriceRegion East US / -20.2
# bestSecondPriceRegion East US 2 / -20.2
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_F48s_v2
# canonicalname f48s_v2
# numberOfCores 48
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 393216
# memoryInMB 98304
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 2.544
# windowsPrice 4.754
# supportPremiumDisk True
# pricePerMemoryLinux 0.0265
# pricePerMemoryWindows 0.0495
# pricePerCoreLinux 0.053
# pricePerCoreWindows 0.099
# bestPriceRegion East US / -20.2
# bestSecondPriceRegion East US 2 / -20.2
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_F32s_v2
# canonicalname f32s_v2
# numberOfCores 32
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 262144
# memoryInMB 65536
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.696
# windowsPrice 3.168
# supportPremiumDisk True
# pricePerMemoryLinux 0.0265
# pricePerMemoryWindows 0.0495
# pricePerCoreLinux 0.053
# pricePerCoreWindows 0.099
# bestPriceRegion East US / -20.2
# bestSecondPriceRegion East US 2 / -20.2
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_F16s_v2
# canonicalname f16s_v2
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 131072
# memoryInMB 32768
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.848
# windowsPrice 1.584
# supportPremiumDisk True
# pricePerMemoryLinux 0.0265
# pricePerMemoryWindows 0.0495
# pricePerCoreLinux 0.053
# pricePerCoreWindows 0.099
# bestPriceRegion East US / -20.2
# bestSecondPriceRegion East US 2 / -20.2
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_F8s_v2
# canonicalname f8s_v2
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 65536
# memoryInMB 16384
# ...
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.06
# windowsPrice 0.09
# supportPremiumDisk False
# pricePerMemoryLinux 0.0343
# pricePerMemoryWindows 0.0514
# pricePerCoreLinux 0.06
# pricePerCoreWindows 0.09
# bestPriceRegion West Central US / -15
# bestSecondPriceRegion West US 2 / -15
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_A0
# canonicalname a0
# numberOfCores 1
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 20480
# memoryInMB 768
# maxDataDiskCount 1
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.02
# windowsPrice 0.02
# supportPremiumDisk False
# pricePerMemoryLinux 0.0267
# pricePerMemoryWindows 0.0267
# pricePerCoreLinux 0.02
# pricePerCoreWindows 0.02
# bestPriceRegion South India / -10
# bestSecondPriceRegion East Asia / 0
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D32s_v3
# canonicalname d32s_v3
# numberOfCores 32
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 262144
# memoryInMB 131072
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.872
# windowsPrice 3.344
# supportPremiumDisk True
# pricePerMemoryLinux 0.0146
# pricePerMemoryWindows 0.0261
# pricePerCoreLinux 0.0585
# pricePerCoreWindows 0.1045
# bestPriceRegion East US / -17.9
# bestSecondPriceRegion East US 2 / -17.9
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D16s_v3
# canonicalname d16s_v3
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 131072
# memoryInMB 65536
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.936
# windowsPrice 1.672
# supportPremiumDisk True
# pricePerMemoryLinux 0.0146
# pricePerMemoryWindows 0.0261
# pricePerCoreLinux 0.0585
# pricePerCoreWindows 0.1045
# bestPriceRegion East US / -17.9
# bestSecondPriceRegion East US 2 / -17.9
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D8s_v3
# canonicalname d8s_v3
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 65536
# memoryInMB 32768
# maxDataDiskCount 16
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.468
# windowsPrice 0.836
# supportPremiumDisk True
# pricePerMemoryLinux 0.0146
# pricePerMemoryWindows 0.0261
# pricePerCoreLinux 0.0585
# pricePerCoreWindows 0.1045
# bestPriceRegion East US / -17.9
# bestSecondPriceRegion East US 2 / -17.9
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D4s_v3
# canonicalname d4s_v3
# numberOfCores 4
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 32768
# memoryInMB 16384
# maxDataDiskCount 8
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.234
# windowsPrice 0.418
# supportPremiumDisk True
# pricePerMemoryLinux 0.0146
# pricePerMemoryWindows 0.0261
# pricePerCoreLinux 0.0585
# pricePerCoreWindows 0.1045
# bestPriceRegion East US / -17.9
# bestSecondPriceRegion East US 2 / -17.9
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_D2s_v3
# canonicalname d2s_v3
# numberOfCores 2
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 16384
# memoryInMB 8192
# maxDataDiskCount 4
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.117
# windowsPrice 0.209
# supportPremiumDisk True
# pricePerMemoryLinux 0.0146
# pricePerMemoryWindows 0.0261
# pricePerCoreLinux 0.0585
# pricePerCoreWindows 0.1045
# bestPriceRegion East US / -17.9
# bestSecondPriceRegion East US 2 / -17.9
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_F16s
# canonicalname f16s
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 65536
# memoryInMB 32768
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.996
# windowsPrice 1.732
# supportPremiumDisk True
# pricePerMemoryLinux 0.0311
# pricePerMemoryWindows 0.0541
# pricePerCoreLinux 0.0623
# pricePerCoreWindows 0.1083
# bestPriceRegion Central India / -20.7
# bestSecondPriceRegion East US / -20.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_F8s
# canonicalname f8s
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 32768
# memoryInMB 16384
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.498
# windowsPrice 0.866
# supportPremiumDisk True
# pricePerMemoryLinux 0.0311
# pricePerMemoryWindows 0.0541
# pricePerCoreLinux 0.0623
# pricePerCoreWindows 0.1083
# bestPriceRegion Central India / -20.7
# bestSecondPriceRegion East US / -20.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_F4s
# canonicalname f4s
# numberOfCores 4
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 16384
# memoryInMB 8192
# maxDataDiskCount 16
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.249
# windowsPrice 0.433
# supportPremiumDisk True
# pricePerMemoryLinux 0.0311
# pricePerMemoryWindows 0.0541
# pricePerCoreLinux 0.0623
# pricePerCoreWindows 0.1083
# bestPriceRegion Central India / -20.5
# bestSecondPriceRegion East US / -20.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_F2s
# canonicalname f2s
# numberOfCores 2
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 8192
# memoryInMB 4096
# maxDataDiskCount 8
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.124
# windowsPrice 0.216
# supportPremiumDisk True
# pricePerMemoryLinux 0.031
# pricePerMemoryWindows 0.054
# pricePerCoreLinux 0.062
# pricePerCoreWindows 0.108
# bestPriceRegion Central India / -20.3
# bestSecondPriceRegion East US / -20.2
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_F1s
# canonicalname f1s
# numberOfCores 1
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 4096
# memoryInMB 2048
# maxDataDiskCount 4
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.062
# windowsPrice 0.108
# supportPremiumDisk True
# pricePerMemoryLinux 0.031
# pricePerMemoryWindows 0.054
# pricePerCoreLinux 0.062
# pricePerCoreWindows 0.108
# bestPriceRegion Central India / -21
# bestSecondPriceRegion East US / -19.8
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_DS15_v2
# canonicalname ds15_v2
# numberOfCores 20
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 286720
# memoryInMB 143360
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.852
# windowsPrice 2.639
# supportPremiumDisk True
# pricePerMemoryLinux 0.0132
# pricePerMemoryWindows 0.0189
# pricePerCoreLinux 0.0926
# pricePerCoreWindows 0.1319
# bestPriceRegion East US 2 / -19.3
# bestSecondPriceRegion West US 2 / -19.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_DS14_v2
# canonicalname ds14_v2
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 229376
# memoryInMB 114688
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.482
# windowsPrice 2.111
# supportPremiumDisk True
# pricePerMemoryLinux 0.0132
# pricePerMemoryWindows 0.0188
# pricePerCoreLinux 0.0926
# pricePerCoreWindows 0.1319
# bestPriceRegion East US 2 / -19.3
# bestSecondPriceRegion West US 2 / -19.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_DS13_v2
# canonicalname ds13_v2
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 114688
# memoryInMB 57344
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.741
# windowsPrice 1.056
# supportPremiumDisk True
# pricePerMemoryLinux 0.0132
# pricePerMemoryWindows 0.0189
# pricePerCoreLinux 0.0926
# pricePerCoreWindows 0.132
# bestPriceRegion East US 2 / -19.3
# bestSecondPriceRegion West US 2 / -19.3
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_DS12_v2
# canonicalname ds12_v2
# numberOfCores 4
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 57344
# memoryInMB 28672
# maxDataDiskCount 16
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.37
# windowsPrice 0.528
# supportPremiumDisk True
# pricePerMemoryLinux 0.0132
# pricePerMemoryWindows 0.0189
# pricePerCoreLinux 0.0925
# pricePerCoreWindows 0.132
# bestPriceRegion East US 2 / -19.2
# bestSecondPriceRegion West US 2 / -19.2
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_DS11_v2
# canonicalname ds11_v2
# numberOfCores 2
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 28672
# memoryInMB 14336
# maxDataDiskCount 8
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.185
# windowsPrice 0.264
# supportPremiumDisk True
# pricePerMemoryLinux 0.0132
# pricePerMemoryWindows 0.0189
# pricePerCoreLinux 0.0925
# pricePerCoreWindows 0.132
# bestPriceRegion East US 2 / -19.5
# bestSecondPriceRegion West US 2 / -19.5
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_DS5_v2
# canonicalname ds5_v2
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 114688
# memoryInMB 57344
# maxDataDiskCount 64
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 1.117
# windowsPrice 2.016
# supportPremiumDisk True
# pricePerMemoryLinux 0.0199
# pricePerMemoryWindows 0.036
# pricePerCoreLinux 0.0698
# pricePerCoreWindows 0.126
# bestPriceRegion East US 2 / -18
# bestSecondPriceRegion West US 2 / -18
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_DS4_v2
# canonicalname ds4_v2
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 57344
# memoryInMB 28672
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.559
# windowsPrice 1.008
# supportPremiumDisk True
# pricePerMemoryLinux 0.02
# pricePerMemoryWindows 0.036
# pricePerCoreLinux 0.0699
# pricePerCoreWindows 0.126
# bestPriceRegion East US 2 / -18.1
# bestSecondPriceRegion West US 2 / -18.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_DS3_v2
# canonicalname ds3_v2
# numberOfCores 4
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 28672
# memoryInMB 14336
# maxDataDiskCount 16
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.279
# windowsPrice 0.504
# supportPremiumDisk True
# pricePerMemoryLinux 0.0199
# pricePerMemoryWindows 0.036
# pricePerCoreLinux 0.0698
# pricePerCoreWindows 0.126
# bestPriceRegion East US 2 / -17.9
# bestSecondPriceRegion West US 2 / -17.9
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_DS2_v2
# canonicalname ds2_v2
# numberOfCores 2
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 14336
# memoryInMB 7168
# maxDataDiskCount 8
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.14
# windowsPrice 0.252
# supportPremiumDisk True
# pricePerMemoryLinux 0.02
# pricePerMemoryWindows 0.036
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.126
# bestPriceRegion East US 2 / -18.6
# bestSecondPriceRegion West US 2 / -18.6
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_DS1_v2
# canonicalname ds1_v2
# numberOfCores 1
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 7168
# memoryInMB 3584
# maxDataDiskCount 4
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.07
# windowsPrice 0.126
# supportPremiumDisk True
# pricePerMemoryLinux 0.02
# pricePerMemoryWindows 0.036
# pricePerCoreLinux 0.07
# pricePerCoreWindows 0.126
# bestPriceRegion East US 2 / -18.6
# bestSecondPriceRegion West US 2 / -18.6
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_B20ms
# canonicalname b20ms
# numberOfCores 20
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 163840
# memoryInMB 81920
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.992
# windowsPrice 1.072
# supportPremiumDisk True
# pricePerMemoryLinux 0.0124
# pricePerMemoryWindows 0.0134
# pricePerCoreLinux 0.0496
# pricePerCoreWindows 0.0536
# bestPriceRegion East US / -16.1
# bestSecondPriceRegion East US 2 / -16.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_B16ms
# canonicalname b16ms
# numberOfCores 16
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 131072
# memoryInMB 65536
# maxDataDiskCount 32
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.794
# windowsPrice 0.858
# supportPremiumDisk True
# pricePerMemoryLinux 0.0124
# pricePerMemoryWindows 0.0134
# pricePerCoreLinux 0.0496
# pricePerCoreWindows 0.0536
# bestPriceRegion East US / -16.1
# bestSecondPriceRegion East US 2 / -16.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_B12ms
# canonicalname b12ms
# numberOfCores 12
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 98304
# memoryInMB 49152
# maxDataDiskCount 16
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.595
# windowsPrice 0.643
# supportPremiumDisk True
# pricePerMemoryLinux 0.0124
# pricePerMemoryWindows 0.0134
# pricePerCoreLinux 0.0496
# pricePerCoreWindows 0.0536
# bestPriceRegion East US / -16.1
# bestSecondPriceRegion East US 2 / -16.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_B8ms
# canonicalname b8ms
# numberOfCores 8
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 65536
# memoryInMB 32768
# maxDataDiskCount 16
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.397
# windowsPrice 0.429
# supportPremiumDisk True
# pricePerMemoryLinux 0.0124
# pricePerMemoryWindows 0.0134
# pricePerCoreLinux 0.0496
# pricePerCoreWindows 0.0536
# bestPriceRegion East US / -16.1
# bestSecondPriceRegion East US 2 / -16.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_B4ms
# canonicalname b4ms
# numberOfCores 4
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 32768
# memoryInMB 16384
# maxDataDiskCount 8
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.198
# windowsPrice 0.214
# supportPremiumDisk True
# pricePerMemoryLinux 0.0124
# pricePerMemoryWindows 0.0134
# pricePerCoreLinux 0.0495
# pricePerCoreWindows 0.0535
# bestPriceRegion East US / -16.2
# bestSecondPriceRegion East US 2 / -16.2
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_B2s
# canonicalname b2s
# numberOfCores 2
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 8192
# memoryInMB 4096
# maxDataDiskCount 4
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.0496
# windowsPrice 0.0576
# supportPremiumDisk True
# pricePerMemoryLinux 0.0124
# pricePerMemoryWindows 0.0144
# pricePerCoreLinux 0.0248
# pricePerCoreWindows 0.0288
# bestPriceRegion East US / -16.1
# bestSecondPriceRegion East US 2 / -16.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_B2ms
# canonicalname b2ms
# numberOfCores 2
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 16384
# memoryInMB 8192
# maxDataDiskCount 4
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.0992
# windowsPrice 0.107
# supportPremiumDisk True
# pricePerMemoryLinux 0.0124
# pricePerMemoryWindows 0.0134
# pricePerCoreLinux 0.0496
# pricePerCoreWindows 0.0535
# bestPriceRegion East US / -16.1
# bestSecondPriceRegion East US 2 / -16.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_B1s
# canonicalname b1s
# numberOfCores 1
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 4096
# memoryInMB 1024
# maxDataDiskCount 2
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.0124
# windowsPrice 0.0164
# supportPremiumDisk True
# pricePerMemoryLinux 0.0124
# pricePerMemoryWindows 0.0164
# pricePerCoreLinux 0.0124
# pricePerCoreWindows 0.0164
# bestPriceRegion East US / -16.1
# bestSecondPriceRegion East US 2 / -16.1
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_B1ms
# canonicalname b1ms
# numberOfCores 1
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 4096
# memoryInMB 2048
# maxDataDiskCount 2
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.0248
# windowsPrice 0.0288
# supportPremiumDisk True
# pricePerMemoryLinux 0.0124
# pricePerMemoryWindows 0.0144
# pricePerCoreLinux 0.0248
# pricePerCoreWindows 0.0288
# bestPriceRegion East US / -16.5
# bestSecondPriceRegion West US 2 / -16.5
# modifiedDate 2020-11-15 10:01:12Z
# name Standard_B1ls
# canonicalname b1ls
# numberOfCores 1
# osDiskSizeInMB 1047552
# resourceDiskSizeInMB 4096
# memoryInMB 512
# maxDataDiskCount 2
# regionId westus
# regionName West US
# currency USD
# isTaxIncluded False
# isLowPriority False
# linuxPrice 0.0062
# windowsPrice 0.0108
# supportPremiumDisk True
# pricePerMemoryLinux 0.0124
# pricePerMemoryWindows 0.0216
# pricePerCoreLinux 0.0062
# pricePerCoreWindows 0.0108
# bestPriceRegion East US / -16.1
# bestSecondPriceRegion East US 2 / -16.1
# modifiedDate 2020-11-15 10:01:12Z

# %%
 
price = pd.DataFrame.from_dict(jdata, orient='columns')

# %%
price.head(10)
# Out:
#                    name canonicalname  numberOfCores  osDiskSizeInMB  \
# 0     Standard_E96as_v4      e96as_v4             96         1047552
# 1  Standard_E96-48as_v4   e96-48as_v4             96         1047552
# 2  Standard_E96-24as_v4   e96-24as_v4             96         1047552
# 3     Standard_E64as_v4      e64as_v4             64         1047552
# 4  Standard_E64-32as_v4   e64-32as_v4             64         1047552
# 5  Standard_E64-16as_v4   e64-16as_v4             64         1047552
# 6     Standard_E48as_v4      e48as_v4             48         1047552
# 7     Standard_E32as_v4      e32as_v4             32         1047552
# 8  Standard_E32-16as_v4   e32-16as_v4             32         1047552
# 9   Standard_E32-8as_v4    e32-8as_v4             32         1047552
#
#    resourceDiskSizeInMB  memoryInMB  maxDataDiskCount regionId regionName  \
# 0               1376256      688128                32   westus    West US
# 1               1376256      688128                32   westus    West US
# 2               1376256      688128                32   westus    West US
# 3                884736      524288                32   westus    West US
# 4                884736      524288                32   westus    West US
# 5                884736      524288                32   westus    West US
# 6                786432      393216                32   westus    West US
# 7                524288      262144                32   westus    West US
# 8                524288      262144                32   westus    West US
# 9                524288      262144                32   westus    West US
#
#   currency  ...  linuxPrice  windowsPrice  supportPremiumDisk  \
# 0      USD  ...        6.72        11.136                True
# 1      USD  ...        6.72        11.136                True
# 2      USD  ...        6.72        11.136                True
# 3      USD  ...        4.48         7.424                True
# 4      USD  ...        4.48         7.424                True
# 5      USD  ...        4.48         7.424                True
# 6      USD  ...        3.36         5.568                True
# 7      USD  ...        2.24         3.712                True
# 8      USD  ...        2.24         3.712                True
# 9      USD  ...        2.24         3.712                True
#
#    pricePerMemoryLinux  pricePerMemoryWindows  pricePerCoreLinux  \
# 0               0.0100                 0.0166               0.07
# 1               0.0100                 0.0166               0.07
# 2               0.0100                 0.0166               0.07
# 3               0.0088                 0.0145               0.07
# 4               0.0088                 0.0145               0.07
# 5               0.0088                 0.0145               0.07
# 6               0.0087                 0.0145               0.07
# 7               0.0088                 0.0145               0.07
# 8               0.0088                 0.0145               0.07
# 9               0.0088                 0.0145               0.07
#
#    pricePerCoreWindows        bestPriceRegion  bestSecondPriceRegion  \
# 0                0.116  Central India / -43.3          East US / -10
# 1                0.116          East US / -10        East US 2 / -10
# 2                0.116          East US / -10        East US 2 / -10
# 3                0.116  Central India / -43.3          East US / -10
# 4                0.116          East US / -10        East US 2 / -10
# 5                0.116          East US / -10        East US 2 / -10
# 6                0.116  Central India / -43.3          East US / -10
# 7                0.116  Central India / -43.3          East US / -10
# 8                0.116          East US / -10        East US 2 / -10
# 9                0.116          East US / -10        East US 2 / -10
#
#            modifiedDate
# 0  2020-11-15 10:01:12Z
# 1  2020-11-15 10:01:12Z
# 2  2020-11-15 10:01:12Z
# 3  2020-11-15 10:01:12Z
# 4  2020-11-15 10:01:12Z
# 5  2020-11-15 10:01:12Z
# 6  2020-11-15 10:01:12Z
# 7  2020-11-15 10:01:12Z
# 8  2020-11-15 10:01:12Z
# 9  2020-11-15 10:01:12Z
#
# [10 rows x 22 columns]

# %% [markdown]
# ##
# <span  STYLE="color: black font-size: 15pt"> Below is to parse and format the json file we scrap from the embedded VM size table. </span>

# %%
def printsize(size_string):
    try:
        size_1=(re.split(r'_v',size_string))[0]
        size_2=(re.split(r'_v',size_string))[1][0]
        size=size_1 + '_v' + size_2
    except:
        size=size_string
    return size

def specs_parse(url):

    #dfs = pd.read_html('https://docs.microsoft.com/en-us/azure/virtual-machines/ev3-esv3-series?toc=/azure/virtual-machines/linux/toc.json&bc=/azure/virtual-machines/linux/breadcrumb/toc.json',header=0)
    dfs =pd.read_html(url,header=0)
    df_norm_concat=pd.DataFrame()
    for df in dfs:
        #print(df.head(10))
        #print(df.Size)
        df_norm=pd.DataFrame() 
        for cols in df.columns.values:
            if cols == 'Size':
                df_norm['Size']=df[cols].apply(lambda x: printsize(x)).apply(lambda x:x.split(' ')[0])
            if 'CPU' in cols:
                df_norm['VCPU']=df[cols] 
            if 'memory' in cols.lower():
                df_norm['Memory']=df[cols]
            if 'max data' in cols.lower():
                df_norm['Max data disks']=df[cols]
            if 'storage (ssd)' in cols.lower():
                df_norm['Temporary Storage SSD(GB)']=df[cols]
            if 'max cached'in cols.lower():
                df_norm['Max cached IO throughput: IOPS/MBps (cache size in GiB)']=df[cols]
            if 'max uncached'in cols.lower() or 'max burst uncached' in cols.lower():  
                df_norm['Max uncached IO throughput: IOPS/MBps']=df[cols]
            if 'network bandwidth' in cols.lower():
                df_norm['Network bandwidth']=pd.to_numeric(df[cols].astype(str).apply(lambda x:x.split(' ')[0]),errors='coerce')
            if 'Max data disks/throughput: IOPS' in cols: 
                df_norm['Max data disks']=pd.to_numeric(df[cols].apply(lambda x:x.split('/')[0]),errors='coerce')
                df_norm['Max IO throughput']=df[cols].apply(lambda x:x.split('/')[1])
        df_norm_concat=df_norm_concat.append(df_norm ) 
    return(df_norm_concat)

# %%
specs_parse('https://docs.microsoft.com/en-us/azure/virtual-machines/fsv2-series?toc=/azure/virtual-machines/linux/toc.json&bc=/azure/virtual-machines/linux/breadcrumb/toc.json')
# Out:
#                Size  VCPU  Memory  Temporary Storage SSD(GB)  Max data disks  \
# 0   Standard_F2s_v2     2       4                         16               4
# 1   Standard_F4s_v2     4       8                         32               8
# 2   Standard_F8s_v2     8      16                         64              16
# 3  Standard_F16s_v2    16      32                        128              32
# 4  Standard_F32s_v2    32      64                        256              32
# 5  Standard_F48s_v2    48      96                        384              32
# 6  Standard_F64s_v2    64     128                        512              32
# 7  Standard_F72s_v2    72     144                        576              32
#
#   Max cached IO throughput: IOPS/MBps (cache size in GiB)  \
# 0                                       4000/31 (32)
# 1                                       8000/63 (64)
# 2                                    16000/127 (128)
# 3                                    32000/255 (256)
# 4                                    64000/512 (512)
# 5                                    96000/768 (768)
# 6                                 128000/1024 (1024)
# 7                                 144000/1152 (1520)
#
#   Max uncached IO throughput: IOPS/MBps  Network bandwidth
# 0                               3200/47                875
# 1                               6400/95               1750
# 2                             12800/190               3500
# 3                             25600/380               7000
# 4                             51200/750              14000
# 5                            76800/1100              21000
# 6                            80000/1100              28000
# 7                            80000/1100              30000

# %%
specs_parse('https://docs.microsoft.com/en-us/azure/virtual-machines/dv2-dsv2-series-memory?toc=/azure/virtual-machines/linux/toc.json&bc=/azure/virtual-machines/linux/breadcrumb/toc.json')
# Out:
#                Size  VCPU  Memory  Temporary Storage SSD(GB)  Max data disks  \
# 0   Standard_D11_v2     2      14                        100               8
# 1   Standard_D12_v2     4      28                        200              16
# 2   Standard_D13_v2     8      56                        400              32
# 3   Standard_D14_v2    16     112                        800              64
# 4   Standard_D15_v2    20     140                       1000              64
# 0  Standard_DS11_v2     2      14                         28               8
# 1  Standard_DS12_v2     4      28                         56              16
# 2  Standard_DS13_v2     8      56                        112              32
# 3  Standard_DS14_v2    16     112                        224              64
# 4  Standard_DS15_v2    20     140                        280              64
#
#   Max IO throughput  Network bandwidth  \
# 0             8x500               1500
# 1            16x500               3000
# 2            32x500               6000
# 3            64x500              12000
# 4            64x500              25000
# 0               NaN               1500
# 1               NaN               3000
# 2               NaN               6000
# 3               NaN              12000
# 4               NaN              25000
#
#   Max cached IO throughput: IOPS/MBps (cache size in GiB)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 0                                       8000/64 (72)
# 1                                    16000/128 (144)
# 2                                    32000/256 (288)
# 3                                    64000/512 (576)
# 4                                    80000/640 (720)
#
#   Max uncached IO throughput: IOPS/MBps
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 0                               6400/96
# 1                             12800/192
# 2                             25600/384
# 3                             51200/768
# 4                             64000/960

# %%
specs_parse('https://docs.microsoft.com/en-us/azure/virtual-machines/dv3-dsv3-series?toc=/azure/virtual-machines/linux/toc.json&bc=/azure/virtual-machines/linux/breadcrumb/toc.json')
# Out:
#                Size  VCPU  Memory  Temporary Storage SSD(GB)  Max data disks  \
# 0    Standard_D2_v3     2       8                         50               4
# 1    Standard_D4_v3     4      16                        100               8
# 2    Standard_D8_v3     8      32                        200              16
# 3   Standard_D16_v3    16      64                        400              32
# 4   Standard_D32_v3    32     128                        800              32
# 5   Standard_D48_v3    48     192                       1200              32
# 6   Standard_D64_v3    64     256                       1600              32
# 0   Standard_D2s_v3     2       8                         16               4
# 1   Standard_D4s_v3     4      16                         32               8
# 2   Standard_D8s_v3     8      32                         64              16
# 3  Standard_D16s_v3    16      64                        128              32
# 4  Standard_D32s_v3    32     128                        256              32
# 5  Standard_D48s_v3    48     192                        384              32
# 6  Standard_D64s_v3    64     256                        512              32
#
#    Network bandwidth Max cached IO throughput: IOPS/MBps (cache size in GiB)  \
# 0                NaN                                                NaN
# 1                NaN                                                NaN
# 2                NaN                                                NaN
# 3                NaN                                                NaN
# 4                NaN                                                NaN
# 5                NaN                                                NaN
# 6                NaN                                                NaN
# 0                NaN                                       4000/32 (50)
# 1                NaN                                      8000/64 (100)
# 2                NaN                                    16000/128 (200)
# 3                NaN                                    32000/256 (400)
# 4                NaN                                    64000/512 (800)
# 5                NaN                                   96000/768 (1200)
# 6                NaN                                 128000/1024 (1600)
#
#   Max uncached IO throughput: IOPS/MBps
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 0                              4000/100
# 1                              8000/200
# 2                             16000/400
# 3                             32000/800
# 4                            64000/1600
# 5                            80000/2000
# 6                            80000/2000

# %%
specs_parse('https://docs.microsoft.com/en-us/azure/virtual-machines/ev3-esv3-series?toc=/azure/virtual-machines/linux/toc.json&bc=/azure/virtual-machines/linux/breadcrumb/toc.json')
# Out:
#                 Size  VCPU  Memory  Temporary Storage SSD(GB)  Max data disks  \
# 0     Standard_E2_v3     2      16                         50               4
# 1     Standard_E4_v3     4      32                        100               8
# 2     Standard_E8_v3     8      64                        200              16
# 3    Standard_E16_v3    16     128                        400              32
# 4    Standard_E20_v3    20     160                        500              32
# 5    Standard_E32_v3    32     256                        800              32
# 6    Standard_E48_v3    48     384                       1200              32
# 7    Standard_E64_v3    64     432                       1600              32
# 8   Standard_E64i_v3    64     432                       1600              32
# 0    Standard_E2s_v3     2      16                         32               4
# 1    Standard_E4s_v3     4      32                         64               8
# 2    Standard_E8s_v3     8      64                        128              16
# 3   Standard_E16s_v3    16     128                        256              32
# 4   Standard_E20s_v3    20     160                        320              32
# 5   Standard_E32s_v3    32     256                        512              32
# 6   Standard_E48s_v3    48     384                        768              32
# 7   Standard_E64s_v3    64     432                        864              32
# 8  Standard_E64is_v3    64     432                        864              32
#
#    Network bandwidth Max cached IO throughput: IOPS/MBps (cache size in GiB)  \
# 0                NaN                                                NaN
# 1                NaN                                                NaN
# 2                NaN                                                NaN
# 3                NaN                                                NaN
# 4                NaN                                                NaN
# 5                NaN                                                NaN
# 6                NaN                                                NaN
# 7                NaN                                                NaN
# 8                NaN                                                NaN
# 0                NaN                                       4000/32 (50)
# 1                NaN                                      8000/64 (100)
# 2                NaN                                    16000/128 (200)
# 3                NaN                                    32000/256 (400)
# 4                NaN                                    40000/320 (400)
# 5                NaN                                    64000/512 (800)
# 6                NaN                                   96000/768 (1200)
# 7                NaN                                 128000/1024 (1600)
# 8                NaN                                 128000/1024 (1600)
#
#   Max uncached IO throughput: IOPS/MBps
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 0                               3200/48
# 1                               6400/96
# 2                             12800/192
# 3                             25600/384
# 4                             32000/480
# 5                             51200/768
# 6                            76800/1152
# 7                            80000/1200
# 8                            80000/1200

# %%
specs_parse('https://docs.microsoft.com/en-us/azure/virtual-machines/edv4-edsv4-series?toc=/azure/virtual-machines/linux/toc.json&bc=/azure/virtual-machines/linux/breadcrumb/toc.json')
# Out:
#                 Size  VCPU  Memory  Temporary Storage SSD(GB)  Max data disks  \
# 0    Standard_E2d_v4     2      16                         75               4
# 1    Standard_E4d_v4     4      32                        150               8
# 2    Standard_E8d_v4     8      64                        300              16
# 3   Standard_E16d_v4    16     128                        600              32
# 4   Standard_E20d_v4    20     160                        750              32
# 5   Standard_E32d_v4    32     256                       1200              32
# 6   Standard_E48d_v4    48     384                       1800              32
# 7   Standard_E64d_v4    64     504                       2400              32
# 0   Standard_E2ds_v4     2      16                         75               4
# 1   Standard_E4ds_v4     4      32                        150               8
# 2   Standard_E8ds_v4     8      64                        300              16
# 3  Standard_E16ds_v4    16     128                        600              32
# 4  Standard_E20ds_v4    20     160                        750              32
# 5  Standard_E32ds_v4    32     256                       1200              32
# 6  Standard_E48ds_v4    48     384                       1800              32
# 7  Standard_E64ds_v4    64     504                       2400              32
#
#   Max cached IO throughput: IOPS/MBps (cache size in GiB)  Network bandwidth  \
# 0                                          19000/120                    1000
# 1                                          38500/242                    2000
# 2                                          77000/485                    4000
# 3                                         154000/968                    8000
# 4                                        193000/1211                   10000
# 5                                        308000/1936                   16000
# 6                                        462000/2904                   24000
# 7                                        615000/3872                   30000
# 0                                      19000/120(50)                    1000
# 1                                     38500/242(100)                    2000
# 2                                     77000/485(200)                    4000
# 3                                    154000/968(400)                    8000
# 4                                   193000/1211(500)                   10000
# 5                                   308000/1936(800)                   16000
# 6                                  462000/2904(1200)                   24000
# 7                                  615000/3872(1600)                   30000
#
#   Max uncached IO throughput: IOPS/MBps
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 0                               3200/48
# 1                               6400/96
# 2                             12800/192
# 3                             25600/384
# 4                             32000/480
# 5                             51200/768
# 6                            76800/1152
# 7                            80000/1200

# %%
specs_parse('https://docs.microsoft.com/en-us/azure/virtual-machines/fsv2-series?toc=/azure/virtual-machines/linux/toc.json&bc=/azure/virtual-machines/linux/breadcrumb/toc.json')
# Out:
#                Size  VCPU  Memory  Temporary Storage SSD(GB)  Max data disks  \
# 0   Standard_F2s_v2     2       4                         16               4
# 1   Standard_F4s_v2     4       8                         32               8
# 2   Standard_F8s_v2     8      16                         64              16
# 3  Standard_F16s_v2    16      32                        128              32
# 4  Standard_F32s_v2    32      64                        256              32
# 5  Standard_F48s_v2    48      96                        384              32
# 6  Standard_F64s_v2    64     128                        512              32
# 7  Standard_F72s_v2    72     144                        576              32
#
#   Max cached IO throughput: IOPS/MBps (cache size in GiB)  \
# 0                                       4000/31 (32)
# 1                                       8000/63 (64)
# 2                                    16000/127 (128)
# 3                                    32000/255 (256)
# 4                                    64000/512 (512)
# 5                                    96000/768 (768)
# 6                                 128000/1024 (1024)
# 7                                 144000/1152 (1520)
#
#   Max uncached IO throughput: IOPS/MBps  Network bandwidth
# 0                               3200/47                875
# 1                               6400/95               1750
# 2                             12800/190               3500
# 3                             25600/380               7000
# 4                             51200/750              14000
# 5                            76800/1100              21000
# 6                            80000/1100              28000
# 7                            80000/1100              30000

# %%
 specs_parse('https://docs.microsoft.com/en-us/azure/virtual-machines/dv2-dsv2-series?toc=/azure/virtual-machines/linux/toc.json&bc=/azure/virtual-machines/linux/breadcrumb/toc.json')
# Out:
#               Size  VCPU  Memory  Temporary Storage SSD(GB)  Max data disks  \
# 0   Standard_D1_v2     1     3.5                         50               4
# 1   Standard_D2_v2     2     7.0                        100               8
# 2   Standard_D3_v2     4    14.0                        200              16
# 3   Standard_D4_v2     8    28.0                        400              32
# 4   Standard_D5_v2    16    56.0                        800              64
# 0  Standard_DS1_v2     1     3.5                          7               4
# 1  Standard_DS2_v2     2     7.0                         14               8
# 2  Standard_DS3_v2     4    14.0                         28              16
# 3  Standard_DS4_v2     8    28.0                         56              32
# 4  Standard_DS5_v2    16    56.0                        112              64
#
#    Network bandwidth Max cached IO throughput: IOPS/MBps (cache size in GiB)  \
# 0                750                                                NaN
# 1               1500                                                NaN
# 2               3000                                                NaN
# 3               6000                                                NaN
# 4              12000                                                NaN
# 0                750                                       4000/32 (43)
# 1               1500                                       8000/64 (86)
# 2               3000                                    16000/128 (172)
# 3               6000                                    32000/256 (344)
# 4              12000                                    64000/512 (688)
#
#   Max uncached IO throughput: IOPS/MBps
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 0                               3200/48
# 1                               6400/96
# 2                             12800/192
# 3                             25600/384
# 4                             51200/768

# %% [markdown]
# ##
# <span  STYLE="color: black font-size: 15pt"> Loop through all VM Types (Compute Optimzed, General Purpose, Memory optimized, etc) and all VM Shapes using reference links </span>

# %%
def get_vmtypes_urls(vmtype_url):
      
        try:
             
            r = requests_retry_session().get(vmtype_url, timeout = 300)
        except Exception as e:
            
            vmtype_urls = []
            return vmtype_urls
        r_content = r.content
        soup = BeautifulSoup(r_content, "html.parser")
         
        vmtype_urls=[]
        vmtype_tuple=tuple()
    
    
        t=soup.find_all("table")[0]
        #print(t)
        for a in t.find_all('a',href=True,text=True):
             
            title=a.get("href")
            a_url=urljoin(vmtype_url,a.get('href'))
            #print(a.get("href"))
            #print(urljoin(vmtype_url,a.get('href')))
         
            if title not in ('sizes-gpu','sizes-hpc'):
                vmtype_tuple=(title, a_url)
                vmtype_urls.append(vmtype_tuple)
         
  
        return vmtype_urls    





def get_vmsize_urls(vmsizes_url):
      
        try:
             
            r = requests_retry_session().get(vmsizes_url, timeout = 300)
        except Exception as e:
            
            vmsize_urls = []
            return vmsize_urls
        r_content = r.content
        soup = BeautifulSoup(r_content, "html.parser")
         
        vmsize_urls=[]
        vmsize_tuple=tuple()
    
        for a in soup.find_all('a',href=True,text=True):
            if a.text.endswith('series'):
                title=a.get("href")
                a_url=urljoin(vmsizes_url,a.get('href'))
            
         
    
                vmsize_tuple=(title, a_url)
                vmsize_urls.append(vmsize_tuple)
         
  
        return vmsize_urls

# %%
get_vmtypes_urls('https://docs.microsoft.com/en-us/azure/virtual-machines/sizes')
# Out:
# [('sizes-general',
#   'https://docs.microsoft.com/en-us/azure/virtual-machines/sizes-general'),
#  ('sizes-compute',
#   'https://docs.microsoft.com/en-us/azure/virtual-machines/sizes-compute'),
#  ('sizes-memory',
#   'https://docs.microsoft.com/en-us/azure/virtual-machines/sizes-memory'),
#  ('sizes-storage',
#   'https://docs.microsoft.com/en-us/azure/virtual-machines/sizes-storage')]

# %%
get_vmsize_urls('https://docs.microsoft.com/en-us/azure/virtual-machines/sizes-general')
# Out:
# [('av2-series',
#   'https://docs.microsoft.com/en-us/azure/virtual-machines/av2-series'),
#  ('dav4-dasv4-series',
#   'https://docs.microsoft.com/en-us/azure/virtual-machines/dav4-dasv4-series'),
#  ('dv4-dsv4-series',
#   'https://docs.microsoft.com/en-us/azure/virtual-machines/dv4-dsv4-series'),
#  ('ddv4-ddsv4-series',
#   'https://docs.microsoft.com/en-us/azure/virtual-machines/ddv4-ddsv4-series'),
#  ('dv3-dsv3-series',
#   'https://docs.microsoft.com/en-us/azure/virtual-machines/dv3-dsv3-series'),
#  ('ev3-esv3-series',
#   'https://docs.microsoft.com/en-us/azure/virtual-machines/ev3-esv3-series'),
#  ('dv2-dsv2-series',
#   'https://docs.microsoft.com/en-us/azure/virtual-machines/dv2-dsv2-series'),
#  ('dcv2-series',
#   'https://docs.microsoft.com/en-us/azure/virtual-machines/dcv2-series')]

# %%
vmtype_list=get_vmtypes_urls('https://docs.microsoft.com/en-us/azure/virtual-machines/sizes')

df_concat=pd.DataFrame()
for vmtype,link in vmtype_list:
    print(vmtype,link)
    vmsize_list=get_vmsize_urls(link)
    for vmsize,link2 in vmsize_list:
        print(vmsize,link2)
        df=pd.DataFrame()
        
        df=specs_parse(link2)
        df['vm_type']=vmtype.split('-')[1].capitalize()
       # .apply(lambda x:x.capitalize())
       #df[cols].astype(str).apply(lambda x:x.split(' ')[0])
        df_concat=df_concat.append(df)
# Out:
# sizes-general https://docs.microsoft.com/en-us/azure/virtual-machines/sizes-general
# av2-series https://docs.microsoft.com/en-us/azure/virtual-machines/av2-series
# dav4-dasv4-series https://docs.microsoft.com/en-us/azure/virtual-machines/dav4-dasv4-series
# dv4-dsv4-series https://docs.microsoft.com/en-us/azure/virtual-machines/dv4-dsv4-series
# ddv4-ddsv4-series https://docs.microsoft.com/en-us/azure/virtual-machines/ddv4-ddsv4-series
# dv3-dsv3-series https://docs.microsoft.com/en-us/azure/virtual-machines/dv3-dsv3-series
# ev3-esv3-series https://docs.microsoft.com/en-us/azure/virtual-machines/ev3-esv3-series
# dv2-dsv2-series https://docs.microsoft.com/en-us/azure/virtual-machines/dv2-dsv2-series
# dcv2-series https://docs.microsoft.com/en-us/azure/virtual-machines/dcv2-series
# sizes-compute https://docs.microsoft.com/en-us/azure/virtual-machines/sizes-compute
# fsv2-series https://docs.microsoft.com/en-us/azure/virtual-machines/fsv2-series
# sizes-memory https://docs.microsoft.com/en-us/azure/virtual-machines/sizes-memory
# dv2-dsv2-series-memory https://docs.microsoft.com/en-us/azure/virtual-machines/dv2-dsv2-series-memory
# eav4-easv4-series https://docs.microsoft.com/en-us/azure/virtual-machines/eav4-easv4-series
# ev3-esv3-series https://docs.microsoft.com/en-us/azure/virtual-machines/ev3-esv3-series
# ev4-esv4-series https://docs.microsoft.com/en-us/azure/virtual-machines/ev4-esv4-series
# edv4-edsv4-series https://docs.microsoft.com/en-us/azure/virtual-machines/edv4-edsv4-series
# m-series https://docs.microsoft.com/en-us/azure/virtual-machines/m-series
# mv2-series https://docs.microsoft.com/en-us/azure/virtual-machines/mv2-series
# sizes-storage https://docs.microsoft.com/en-us/azure/virtual-machines/sizes-storage
# lsv2-series https://docs.microsoft.com/en-us/azure/virtual-machines/lsv2-series

# %%
df_concat.head(10)
# Out:
#               Size  Memory Temporary Storage SSD(GB)  Max data disks  \
# 0   Standard_A1_v2     2.0                        10               2
# 1   Standard_A2_v2     4.0                        20               4
# 2   Standard_A4_v2     8.0                        40               8
# 3   Standard_A8_v2    16.0                        80              16
# 4  Standard_A2m_v2    16.0                        20               4
# 5  Standard_A4m_v2    32.0                        40               8
# 6  Standard_A8m_v2    64.0                        80              16
# 0  Standard_D2a_v4     8.0                        50               4
# 1  Standard_D4a_v4    16.0                       100               8
# 2  Standard_D8a_v4    32.0                       200              16
#
#   Max IO throughput  Network bandwidth  vm_type  VCPU  \
# 0             2x500              250.0  General   NaN
# 1             4x500              500.0  General   NaN
# 2             8x500             1000.0  General   NaN
# 3            16x500             2000.0  General   NaN
# 4             4x500              500.0  General   NaN
# 5             8x500             1000.0  General   NaN
# 6            16x500             2000.0  General   NaN
# 0               NaN             1000.0  General   2.0
# 1               NaN             2000.0  General   4.0
# 2               NaN             4000.0  General   8.0
#
#   Max cached IO throughput: IOPS/MBps (cache size in GiB)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   Max uncached IO throughput: IOPS/MBps
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN

# %%
df_final=df_concat[['vm_type','Size','VCPU','Memory','Temporary Storage SSD(GB)','Max data disks','Max IO throughput','Max cached IO throughput: IOPS/MBps (cache size in GiB)', 'Max uncached IO throughput: IOPS/MBps','Network bandwidth']]
df_final.head(100)
# Out:
#     vm_type              Size  VCPU  Memory Temporary Storage SSD(GB)  \
# 0   General    Standard_A1_v2   NaN     2.0                        10
# 1   General    Standard_A2_v2   NaN     4.0                        20
# 2   General    Standard_A4_v2   NaN     8.0                        40
# 3   General    Standard_A8_v2   NaN    16.0                        80
# 4   General   Standard_A2m_v2   NaN    16.0                        20
# ..      ...               ...   ...     ...                       ...
# 2   General  Standard_DC4s_v2   4.0   112.0                       200
# 3   General   Standard_DC8_v2   8.0   168.0                       400
# 0   Compute   Standard_F2s_v2   2.0     4.0                        16
# 1   Compute   Standard_F4s_v2   4.0     8.0                        32
# 2   Compute   Standard_F8s_v2   8.0    16.0                        64
#
#     Max data disks Max IO throughput  \
# 0                2             2x500
# 1                4             4x500
# 2                8             8x500
# 3               16            16x500
# 4                4             4x500
# ..             ...               ...
# 2                4               NaN
# 3                8               NaN
# 0                4               NaN
# 1                8               NaN
# 2               16               NaN
#
#    Max cached IO throughput: IOPS/MBps (cache size in GiB)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 2                                             8000/64
# 3                                           16000/128
# 0                                        4000/31 (32)
# 1                                        8000/63 (64)
# 2                                     16000/127 (128)
#
#    Max uncached IO throughput: IOPS/MBps  Network bandwidth
# 0                                    NaN              250.0
# 1                                    NaN              500.0
# 2                                    NaN             1000.0
# 3                                    NaN             2000.0
# 4                                    NaN              500.0
# ..                                   ...                ...
# 2                                    NaN                2.0
# 3                                    NaN                2.0
# 0                                3200/47              875.0
# 1                                6400/95             1750.0
# 2                              12800/190             3500.0
#
# [100 rows x 10 columns]

# %% [markdown]
# ##
# <span  STYLE="color: black font-size: 15pt"> Join the VM Size and Price dataframes. </span>

# %%
df_price=price[['name','regionName','linuxPrice']]  
df_price.columns = ['name', 'Price Region', 'Linux Price/hour']
#df_price['Linux Price/month']=df_price['Linux Price/hour'].map(lambda x: x * 24 * 31)

## To avoid SettingWithCopyWarning
pd.reset_option('mode.chained_assignment')
with pd.option_context('mode.chained_assignment', None):
    df_price.loc[:, 'Linux Price/month']=df_price['Linux Price/hour'].map(lambda x: x * 24 * 31)

# %%
#pd.merge(product,customer,on='Product_ID')
joined=pd.merge(df_final, df_price,how='left', left_on='Size', right_on='name')

# %%
joined
# Out:
#      vm_type              Size  VCPU  Memory Temporary Storage SSD(GB)  \
# 0    General    Standard_A1_v2   NaN     2.0                        10
# 1    General    Standard_A2_v2   NaN     4.0                        20
# 2    General    Standard_A4_v2   NaN     8.0                        40
# 3    General    Standard_A8_v2   NaN    16.0                        80
# 4    General   Standard_A2m_v2   NaN    16.0                        20
# ..       ...               ...   ...     ...                       ...
# 202  Storage  Standard_L16s_v2  16.0   128.0                       NaN
# 203  Storage  Standard_L32s_v2  32.0   256.0                       NaN
# 204  Storage  Standard_L48s_v2  48.0   384.0                       NaN
# 205  Storage  Standard_L64s_v2  64.0   512.0                       NaN
# 206  Storage  Standard_L80s_v2  80.0   640.0                       NaN
#
#      Max data disks Max IO throughput  \
# 0                 2             2x500
# 1                 4             4x500
# 2                 8             8x500
# 3                16            16x500
# 4                 4             4x500
# ..              ...               ...
# 202              32               NaN
# 203              32               NaN
# 204              32               NaN
# 205              32               NaN
# 206              32               NaN
#
#     Max cached IO throughput: IOPS/MBps (cache size in GiB)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 202                                                NaN
# 203                                                NaN
# 204                                                NaN
# 205                                                NaN
# 206                                                NaN
#
#     Max uncached IO throughput: IOPS/MBps  Network bandwidth  \
# 0                                     NaN              250.0
# 1                                     NaN              500.0
# 2                                     NaN             1000.0
# 3                                     NaN             2000.0
# 4                                     NaN              500.0
# ..                                    ...                ...
# 202                            16000/1280             6400.0
# 203                            32000/1280            12800.0
# 204                            48000/2000                NaN
# 205                            64000/2000                NaN
# 206                            80000/2000                NaN
#
#                  name Price Region  Linux Price/hour  Linux Price/month
# 0      Standard_A1_v2      West US             0.043             31.992
# 1      Standard_A2_v2      West US             0.091             67.704
# 2      Standard_A4_v2      West US             0.191            142.104
# 3      Standard_A8_v2      West US             0.400            297.600
# 4     Standard_A2m_v2      West US             0.149            110.856
# ..                ...          ...               ...                ...
# 202  Standard_L16s_v2      West US             1.376           1023.744
# 203  Standard_L32s_v2      West US             2.752           2047.488
# 204  Standard_L48s_v2      West US             4.128           3071.232
# 205  Standard_L64s_v2      West US             5.504           4094.976
# 206  Standard_L80s_v2      West US             6.880           5118.720
#
# [207 rows x 14 columns]

# %%
joined_selected=joined[['vm_type','Size','VCPU','Memory','Temporary Storage SSD(GB)','Max data disks','Max IO throughput','Max cached IO throughput: IOPS/MBps (cache size in GiB)','Max uncached IO throughput: IOPS/MBps','Network bandwidth','Price Region', 'Linux Price/hour','Linux Price/month']]

# %% [markdown]
# ##
# <span  STYLE="color: black font-size: 15pt"> Output excel workbook with formats. </span>

# %%
# Write out to workbook with format

writer = pd.ExcelWriter("Azure_VM_Size_Price.xlsx", engine='xlsxwriter')
joined_selected.to_excel(writer,sheet_name = 'vmsize_price' )
workbook  = writer.book
worksheet = writer.sheets['vmsize_price']

#font_fmt = workbook.add_format({'font_name': 'Arial', 'font_size': 10})


header_format = workbook.add_format({
    'bold': True,
    'text_wrap': True,
    'valign': 'top',
    'fg_color': '#939DAD',
    'border': 1})

# Write the column headers with the defined format.
for col_num, value in enumerate(joined_selected.columns.values):
    worksheet.write(0, col_num + 1, value, header_format)

    
    
    
# Add some cell formats.
 
format1= workbook.add_format({'num_format': '#,##0.000','border': 1})
format2= workbook.add_format({'font_name': 'Arial', 'font_size': 10,'border': 1})

# Set the column width and format.
worksheet.set_column('A:A', 5,format2 )
worksheet.set_column('B:B', 9,format2 )
worksheet.set_column('C:C', 16,format2 )
worksheet.set_column('D:D', 8,format2 )
worksheet.set_column('E:E', 9,format2 )
worksheet.set_column('F:F', 12,format2)
worksheet.set_column('G:G', 8,format2)
worksheet.set_column('H:H', 12,format2)
worksheet.set_column('I:I', 18,format2 )
worksheet.set_column('J:J', 16,format2 )
worksheet.set_column('K:K', 9,format2 )
worksheet.set_column('L:L', 12, format2)
worksheet.set_column('M:M', 12, format1)
worksheet.set_column('N:N', 13, format1)
writer.save()
